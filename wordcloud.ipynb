# %%
conda install -c conda-forge wordcloud
# Out:
# ...
# Solving environment: done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
df = pd.read_csv("responses.csv")

# %%
df
# Out:
#                                             response
# 0  Friendships are socially passionate and compas...
# 1  A social relationship between individuals that...
# 2  I reference friendship almost exclusively amon...
# 3  Friends are people I enjoy spending time with....
# 4  Friendship is a long-lasting (though it does n...
# 5  Friendship is wanting to spend time together, ...
# 6  Friendship to me is a relationship that persis...
# 7  Friendship is a relationship in which organism...
# 8  It is a state of enduring affection, esteem, i...

# %%
# Start with one person's definition
text = df.response[8]

# Create and generate a word cloud image:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# with all definitions combined
text = " ".join(response for response in df.response)

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(["friend", "friendship", 'Hutcherson', 'friends']) # words we don't want to include in wordcloud (empty for now)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#save as png
wordcloud.to_file("wordcloud.png")
