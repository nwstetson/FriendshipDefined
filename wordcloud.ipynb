# %% [markdown]
# ### Word cloud figure

# %%
# Install wordcloud package
conda install -c conda-forge wordcloud
# Out:
#   Cell In[1], line 2
#     conda install -c conda-forge wordcloud
#           ^
# SyntaxError: invalid syntax

# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
# Using survey responses to peoples' definition of friendship as data
# Examples were omitted so it was just peoples' definitions

dfLong = pd.read_csv("responses.csv") 
dfShort = pd.read_csv("responses_short.csv")

# %% [markdown]
# ## Full version

# %%
# Combine responses
text = " ".join(response for response in dfLong.response)

# Generate a word cloud image
wordcloud = WordCloud(background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

#save as png
wordcloud.to_file("wordcloud_long.png")
#save as pdf
wordcloud.to_file("wordcloud_long.pdf")

# %% [markdown]
# ## Shortened version

# %%
# Combine responses
text = " ".join(response for response in dfShort.response)

# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(['friendship', 'friendships', 'friend', 'friends', 'characterized', 'described', 'humans', 'human'
                 'chimp', 'chimps']) # words we don't want to include in wordcloud (empty for now)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

#save as png
wordcloud.to_file("wordcloud_short.png")
#save as pdf
wordcloud.to_file("wordcloud_short.pdf")
