# %% [markdown]
# ### Word cloud figure

# %%
# Install wordcloud package
conda install -c conda-forge wordcloud

# %%
# Start with loading all necessary libraries
import numpy as np
import pandas as pd
from os import path
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

import matplotlib.pyplot as plt

# %%
# Using survey responses to peoples' definition of friendship as data
# Examples were omitted so it was just peoples' definitions

df = pd.read_csv("responses_short.csv")

# %%
# Start with just one person's definition to test it
text = df.response[1]

# Create and generate a word cloud image:
wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
plt.figure()
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
# with all definitions combined
text = " ".join(response for response in df.response)

# %%
# Create stopword list:
stopwords = set(STOPWORDS)
stopwords.update(['friendship', 'friendships', 'characterized', 'described', 'humans', 'human'
                 'chimp', 'chimps']) # words we don't want to include in wordcloud (empty for now)

# Generate a word cloud image
wordcloud = WordCloud(stopwords=stopwords, background_color="white").generate(text)

# Display the generated image:
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
#save as png
wordcloud.to_file("wordcloud_short.png")
